# %% [markdown]
# The following functions are used send queries to Translator and display the results

# %%
#imports
import json
import requests
from collections import defaultdict
import pandas as pd
import copy
from datetime import datetime as dt
import urllib.parse
import time
from csv import reader
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/99/mq5bcrkd3g92tjqr0mjy0_5156kwnd/T/ipykernel_34445/7363880.py in <module>
#       3 import requests
#       4 from collections import defaultdict
# ----> 5 import pandas as pd
#       6 import copy
#       7 from datetime import datetime as dt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#ARS functions
def submit_to_ars(m,ars_url='https://ars.transltr.io/ars/api',arax_url='https://arax.ncats.io'):
    submit_url=f'{ars_url}/submit'
    response = requests.post(submit_url,json=m)
    try:
        message_id = response.json()['pk']
    except:
        print('fail')
        message_id = None
    print(f'{arax_url}/?source=ARS&id={message_id}')
    return message_id

def retrieve_ars_results(mid,ars_url='https://ars.transltr.io/ars/api'):
    message_url = f'{ars_url}/messages/{mid}?trace=y'
    response = requests.get(message_url)
    j = response.json()
    print( j['status'] )
    results = {}
    for child in j['children']:
        #print(child['status'])
        if child['status']  == 'Done':
            childmessage_id = child['message']
            child_url = f'{ars_url}/messages/{childmessage_id}'
            try:
                child_response = requests.get(child_url).json()
                nresults = len(child_response['fields']['data']['message']['results'])
                if nresults > 0:
                    results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except Exception as e:
                nresults=0
                child['status'] = 'ARS Error'
        elif child['status'] == 'Error':
            nresults=0
            childmessage_id = child['message']
            child_url = f'{ars_url}/messages/{childmessage_id}'
            try:
                child_response = requests.get(child_url).json()
                results[child['actor']['agent']] = {'message':child_response['fields']['data']['message']}
            except Exception as e:
                print(e)
                child['status'] = 'ARS Error'
        else:
            nresults = 0
        #print( child['status'], child['actor']['agent'],nresults )
    return results

# %%
# helper functions
def translate_node_name(list_input, ontology_prefix, sort_by_ontology=False, log=False):
    '''
    translate array of values using the translator name resolver
    will return multiple rows if multiple results returned for one name
    ex: 
        list_test_result = translate(list_test, 'NCBIGene', sort_by_ontology=True)
    get:
        [('MT-ND2', 'NCBIGene:56168'), ('MT-ND2', 'NCBIGene:387315')]
    '''
    # initialize
    list_result = []

    # query for the list of names
    for name in list_input:
        #url_call = urllib.parse.quote(name)
        try:
            #response = requests.post(url_call)
            output_json = resolve_name(name)
            #output_json = response.json()
        except ValueError:
            print("got json error for {}, so skip".format(name))
            continue

        # parse
        for key, value in output_json.items():
            if ontology_prefix in key:
                list_result.append((name, key))
                #Cutting things off at one
                break

    if sort_by_ontology:
        list_result.sort(key = lambda x: int(x[1].split(":")[1]))

    # return
    return list_result

# %%
#utils
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def resolve_name(string):
    url_string=urllib.parse.quote(string)
    name_resolver_url="https://name-resolution-sri.renci.org/lookup?string="
    message_url = f'{name_resolver_url}{string}&offset=0&limit=10'
    response = requests.post(message_url)
    return response.json()

# %%
def getpath_impl(j, fields, i):
    if(j is None or i>=len(fields)):
        return j
    field = fields[i]
    jNext = j[field] if field in j else None
    return getpath_impl(jNext, fields, i+1)

def getpath(j, fields):
    return getpath_impl(j, fields, 0)

# %%
def get_message_from_disk(file="araxResultsSpringHackathon.json"):
    with open(file, 'r') as f:
      data = json.load(f)
    return data

# %%
def get_knowledge_graph(message):
    return getpath(message,["fields","data","message","knowledge_graph"])

# %%
#Returns `nodes` from either a TRAPI knowledge_graph or full response
def get_nodes(json):
    nodes=None
    if "model" in json:
        #We're looking at a full TRAPI message
        nodes = getpath(json,["fields","data","message","knowledge_graph","nodes"])
    elif "nodes" in json:
        #We're looking at just the KG
        nodes = getpath(json,["nodes"])
    return nodes

# %%
#Returns `edges` from either a TRAPI knowledge_graph or full response
def get_edges(json):
    edges=None
    if "model" in json:
        #We're looking at a full TRAPI message
        edges = getpath(json,["fields","data","message","knowledge_graph","edges"])
    elif "edges" in json:
        #We're looking at just the KG
        edges = getpath(json,["edges"])
    return edges

# %%
def get_results(json):
    return getpath(json,["fields","data","message","results"])

# %%
def edge_contains_semmed(edge):
    sources= ["biolink:aggregator_knowledge_source","biolink:knowledge_source"]
    attributes = getpath(edge,["attributes"])
    semmed=False
    #print_json(edge)
    for attribute in attributes:
        attribute_id = getpath(attribute,["attribute_type_id"])
        if attribute_id in sources:
            value = getpath(attribute,["value"])
            #print("value: "+value)
            if value is not None:
                if "semmeddb" in value:
                    semmed=True
                
    return semmed

# %%
example = get_message_from_disk()
kg = get_knowledge_graph(example)

# %%
edges = get_edges(example)
nodes = get_nodes(example)
results = get_results(example)

# %%
total_edges = len(edges.keys())
semmed_count = 0
for key in edges.keys():
    
    if(edge_contains_semmed(edges[key])):
        semmed_count+=1
        #print(key)
print(semmed_count+" of "+total_e)
# Out:
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL472-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201866-biolink:treats-MONDO:0004946
# infores:rtx-kg2:DRUGBANK:DB01404-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1908360-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEBI:81572-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL245067-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201866-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL408403-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200559-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL245067-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2095209-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1237-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3322001-biolink:affects-MONDO:0002909
# infores:rtx-kg2:UniProtKB:P04040-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:83350-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL539-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2107885-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83364-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3188993-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL193-biolink:treats-MONDO:0004946
# infores:rtx-kg2:FMA:83349-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1672002-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1547-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.TARGET:CHEMBL4287-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83350-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1514176-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:67264-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL226335-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1715-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1949934-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1561-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1431-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:FMA:82764-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4297654-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:67243-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL70-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2146146-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL408-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL350221-biolink:affects-MONDO:0004946
# infores:rtx-kg2:FMA:83349-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:FMA:61799-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1334033-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEBI:81588-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1697788-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:FMA:83369-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3559671-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201538-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:FMA:83349-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1162144-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200559-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEBI:37845-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEBI:59951-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82797-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.TARGET:CHEMBL2364711-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1671-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL427216-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200689-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL538973-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL493-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL597-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:FMA:82747-biolink:entity_positively_regulates_entity-MONDO:0004946
# infores:rtx-kg2:FMA:83350-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1603-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL597-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2109087-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEBI:37845-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1096009-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1492000-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL472-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL306823-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1671-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL170988-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1671-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL
biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3121562-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2107869-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1162496-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL393336-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2018096-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL465208-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3349607-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL649-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL393336-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL323356-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL507237-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1275835-biolink:affects-MONDO:0002909
# infores:rtx-kg2:UMLS:C4726948-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL295124-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL429910-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL242011-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108197-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4297514-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201753-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL692-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108052-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2401866-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1289601-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2107085-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4297741-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2396661-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL289191-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83350-biolink:entity_positively_regulates_entity-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3350037-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:FMA:82743-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1566-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1603-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL170988-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1603-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:affects-MONDO:0002909
# infores:rtx-kg2:UniProtKB:P01308-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL408403-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL493737-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1431-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200559-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108052-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL239243-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3409094-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:prevents-MONDO:0004946
# infores:rtx-kg2:FMA:82746-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82787-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEBI:27844-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1272-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1098659-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108964-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:FMA:82743-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:RXNORM:1368647-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200485-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL529888-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL181-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL181-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108446-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2104391-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201497-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1431-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1987697-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2109087-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1236183-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1236183-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4303637-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL50-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:FMA:83350-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL529888-biolink:entity_positively_regulates_entity-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1481-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL410972-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1431-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1566-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3039057-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1237-biolink:treats-MONDO:0002909
# infores:rtx-kg2:UBERON:0000966-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL543467-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL597-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL441687-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2109060-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200689-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4297654-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL529888-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3322001-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEBI:17984-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEBI:81572-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEBI:26523-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3322001-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1159558-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:82746-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2401865-biolink:treats-MONDO:0004946
# infores:rtx-kg2:FMA:83349-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL460033-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1606435-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL170721-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:UBERON:0007113-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:82785-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1950045-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL140-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1603-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL85139-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1715-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:82763-biolink:treats-MONDO:0002909
# infores:rtx-kg2:DRUGBANK:DB13971-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1566-biolink:affects-MONDO:0002909
# infores:rtx-kg2:FMA:82743-biolink:affects-MONDO:0004946
# infores:rtx-kg2:FMA:63891-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1566-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1261-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL43048-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL226335-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL472-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4303637-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3350037-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL145615-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:83350-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL692-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL9-biolink:affects-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1553328-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL309821-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1561-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:83365-biolink:entity_positively_regulates_entity-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL76447-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2103800-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1512355-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1513-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201538-biolink:treats-MONDO:0002909
# infores:rtx-kg2:FMA:74644-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL168-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL4303637-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2103758-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEBI:26523-biolink:entity_positively_regulates_entity-MONDO:0002909
# infores:rtx-kg2:UniProtKB:P04040-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL269277-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201498-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL173373-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL529888-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3121562-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1201866-biolink:disrupts-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1603-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEBI:72544-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEBI:37845-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEBI:35341-biolink:treats-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL465208-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL672-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL2108106-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL3355096-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL715-biolink:affects-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL529888-biolink:disrupts-MONDO:0004946
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL539-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1553328-biolink:prevents-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL413-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL843-biolink:treats-MONDO:0002909
# infores:rtx-kg2:CHEMBL.COMPOUND:CHEMBL1200748-biolink:treats-MONDO:0004946
# infores:rtx-kg2:FMA:82747-biolink:prevents-MONDO:0004946
